# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[8,8,1],[7,9,1],[6,10,0],[5,5,0]], columns=['cgpa', 'profile_score', 'placed'])

# %%
df
# Out:
#    cgpa  profile_score  placed
# 0     8              8       1
# 1     7              9       1
# 2     6             10       0
# 3     5              5       0

# %%
import tensorflow 
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation = 'sigmoid',input_dim = 2))
model.add(Dense(1,activation = 'sigmoid'))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29 (120.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 20 (84.00 B)

# %%
model.get_weights()
# Out:
# [array([[0.2530665 , 0.2530665 ],
#         [0.24494453, 0.24494453]], dtype=float32),
#  array([0.1501937, 0.1501937], dtype=float32),
#  array([[0.30019763],
#         [0.30019763]], dtype=float32),
#  array([0.19377911], dtype=float32)]

# %%
new_weights = [np.array([[0.1 , 0.1 ],
        [0.1  , 0.1]], dtype=np.float32),
 np.array([0., 0.], dtype=np.float32),
 np.array([[0.1 ],
        [0.1]], dtype=np.float32),
 np.array([0.], dtype=np.float32)]

# %%
model.set_weights(new_weights)

# %%
model.get_weights()
# Out:
# [array([[0.1, 0.1],
#         [0.1, 0.1]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.1],
#         [0.1]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
optimizer = keras.optimizers.Adam(learning_rate = 0.001)
model.compile(loss = 'binary_crossentropy',optimizer = optimizer)

# %%
b
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.7173
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.7024
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.7163
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 0.7128
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.6741
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.7060
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - loss: 0.6723
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - loss: 0.7157
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6840
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.6587
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.7019
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6581
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.7278
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.6592
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.6584
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - loss: 0.6830
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.7270
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.7144
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.7112
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.7049
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.7048
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.6843
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.7277
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 0.6844
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.7272
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.6835
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 0.6611
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 0.6609
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.6834
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 0.6610
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.7133
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.7245
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.6742
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.7041
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.6618
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.6742
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.6845
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - loss: 0.6743
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.7255
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.7231
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.7246
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.6839
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.6764
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.7225
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.6999
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.6999
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 0.7240
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6849
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6840
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.6630
