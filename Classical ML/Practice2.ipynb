# %%
import pandas as pd
import numpy as np

# %%
data1 = {
    'X' : [1, 3, 4, 6, 8],
    'Y' : [2, 9, 8, 12, 11]
}

df = pd.DataFrame(data = data1)

print(df)
# Out:
#    X   Y
# 0  1   2
# 1  3   9
# 2  4   8
# 3  6  12
# 4  8  11

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df,df,vmin=None, vmax=None)
plt.show()
