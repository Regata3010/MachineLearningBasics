# %%
import pandas as pd
import numpy as np

# %%
data1 = {
    "col1" : [25, 30, 35, 40, 45, 50, 55, 60]
}

df = pd.DataFrame(data = data1)

print(df)
# Out:
#    col1
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# 5    50
# 6    55
# 7    60

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.hist(figsize = (10,10))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    8 non-null      int64
# dtypes: int64(1)
# memory usage: 196.0 bytes

# %%
df.describe()
# Out:
#             col1
# count   8.000000
# mean   42.500000
# std    12.247449
# min    25.000000
# 25%    33.750000
# 50%    42.500000
# 75%    51.250000
# max    60.000000
